# %% [markdown]
# # EDA of "HPC Jobs Dataset"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Importing dataset

# %%
df = pd.read_csv("filtered_hpc_dataset.csv")

# %%
df.head()
# Out:
#       JobID  SubmitTime  RequestedTime  RunTime  AllocatedProcessors  \
# 3023   7019     4796419          43200    12322                   16
# 3048   7047     4851035          43200      452                   16
# 4110  26226     6745127          36000        6                   16
# 4116  26253     6759830          90000    60107                    8
# 4222  26537     6855164             60        1                  120
#
#       RequestedProcessors  UsedMemory  RequestedMemory  \
# 3023                   16     57344.0         972800.0
# 3048                   16     57344.0         972800.0
# 4110                   16    409600.0         409600.0
# 4116                    8    409600.0         409600.0
# 4222                  120    921600.0         921600.0
#
#       requestedMemory_per_cpu
# 3023                  60800.0
# 3048                  60800.0
# 4110                  25600.0
# 4116                  51200.0
# 4222                   7680.0
